# %% [markdown]
# Q1: Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
#
# Load the dataset using a suitable library like pandas.
# Use the .shape attribute of the DataFrame to get the number of rows (instances) and columns (features) in the dataset.
#
# Q2: What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
#
# Select the column containing flight prices.
# Use a histogram plot (e.g., plt.hist() from matplotlib) to visualize the distribution of flight prices.
#
# Q3: What is the range of prices in the dataset? What is the minimum and maximum price?
#
# Calculate the minimum and maximum values of the flight price column to get the range.
#
# Q4: How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.
#
# Group the dataset by airline and extract the flight price column for each group.
# Create a boxplot (e.g., sns.boxplot() from Seaborn) to compare the flight prices across different airlines.
#
# Q5: Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
#
# Use the boxplot created in the previous question to identify any data points that fall significantly outside the whiskers of the boxplot. These are potential outliers.
# Describe how outliers might impact your analysis, such as skewing the mean or affecting the distribution analysis.
#
# Q6: You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#
# Analyze the flight prices over time, considering features like the date of the flights, months, and seasons.
# Create line plots or bar plots to visualize how flight prices vary over different time periods.
# Present your findings by showing the trends in flight prices across different months or seasons.
#
# Q7: You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#
# Analyze trends in flight prices based on factors like time (months, seasons), day of the week, departure and arrival locations, airline, etc.
# Use line plots, bar plots, or heatmaps to visualize how flight prices change based on these factors.
# Present your findings by showing visualizations that clearly highlight the trends and patterns in flight prices.
#
# Q8: You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#
# Analyze the relationship between flight prices and factors like departure and arrival locations, flight duration, airline, time of booking, etc.
# Use scatter plots, regression analysis, or correlation matrices to explore the relationships between these factors and flight prices.
# Present your findings by providing insights into how different factors influence flight prices, along with supporting visualizations that showcase these relationships.

# %%
import seaborn as sns

# Load the flights dataset from Seaborn
data = sns.load_dataset("flights")

# Get the dimensions of the dataset
rows, columns = data.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
data
# Out:
# Number of rows: 144
# Number of columns: 3
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Create a histogram to visualize the distribution of flight prices
plt.figure(figsize=(10, 6))
sns.histplot(data['passengers'], bins=20, kde=True)
plt.xlabel('Number of Passengers')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Passengers')
plt.show()

# %%
min_price = data['passengers'].min()
max_price = data['passengers'].max()
price_range = max_price - min_price

print(f"Minimum Price: {min_price}")
print(f"Maximum Price: {max_price}")
print(f"Price Range: {price_range}")
# Out:
# Minimum Price: 104
# Maximum Price: 622
# Price Range: 518

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='year', y='passengers')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Number of Passengers by Year')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='year', y='passengers')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Number of Passengers by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by month and calculate the mean number of passengers for each month
monthly_avg_passengers = data.groupby('month')['passengers'].mean()

# Create a line plot to show the trend of average passengers over the months
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_avg_passengers.index, y=monthly_avg_passengers.values)
plt.xlabel('Month')
plt.ylabel('Average Number of Passengers')
plt.title('Average Number of Passengers by Month')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by year and calculate the mean number of passengers for each year
yearly_avg_passengers = data.groupby('year')['passengers'].mean()

# Create a line plot to show the trend of average passengers over the years
plt.figure(figsize=(10, 6))
sns.lineplot(x=yearly_avg_passengers.index, y=yearly_avg_passengers.values)
plt.xlabel('Year')
plt.ylabel('Average Number of Passengers')
plt.title('Average Number of Passengers by Year')
plt.xticks(rotation=45)
plt.show()

# %%
# Group by year and month and calculate the mean number of passengers for each year and month combination
year_month_avg_passengers = data.groupby(['year', 'month'])['passengers'].mean().unstack()

# Create a heatmap to show how the average number of passengers varies across years and months
plt.figure(figsize=(12, 8))
sns.heatmap(year_month_avg_passengers, cmap='YlGnBu', annot=True, fmt=".0f", linewidths=.5)
plt.xlabel('Month')
plt.ylabel('Year')
plt.title('Average Number of Passengers by Year and Month')
plt.show()
